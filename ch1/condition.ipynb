# %% [markdown]
# ###제어문
#
# - if
# - while
# - for
#
# - 숫자가 짝수면 짝수라고 출력, 아니면 홀수라고 출력

# %%
num = 5

# if 문 : bool 자료형
if num % 2 == 0:
    print("짝수")
else:
    print('홀수')

# %%
# SyntaxError = 문법오류
# - if num = 2:
# - print("짝수")

# - >, <, >=,<= ==, !=, : True, False
# in, not in
a=200
# a가 100보다 작다면 a는 100보다 작다 출력
if a < 100:
    print("a는 100보다 작다")

# a가 100보다 크고 200이하라면 a는 100과 200사이의 수 이다. 출력
